# %%
def number_guesser():
    import random 
    x=random.randint(1,6)
    y=int(input('Enter the number you gueesed:-'))
    
    if x==y:
        print('YOU GUESSED THE RIGHT NUMBER')
        
    else:
        print('YOU GUESSED THE WRONG ONE')
    


    m=input('DO YOU WANT TO TRY AGAIN, WRITE YES or NO:')
    if m=='YES':
        number_guesser()
    else:
        print('Better Luck Next Time')

number_guesser()

# %%
def comparision(x,y):
        
        y = int(input('ENTER YOUR ANOTHER GUESS:'))
        print('THE NUMBER YOU NOW GUESSED IS:',y)
        if x==y:
            print('NOW THE GUESSED NUMBER IS RIGHT THE ANSWER WAS:',x)
            
        
        elif x!=y:
            if x-y>=50:
                print('YOU ARE TOO FAR AWAY')
                comparision(x,y)
            elif x-y>=30 and x-y<50:
                print('YOU ARE MUCH FAR FROM NUMBER')
                comparision(x,y)
            elif x-y>=20 and x-y<30:
                print('YOU ARE STILL FAR')
                comparision(x,y)
            elif x-y>=10 and x-y<20:
                print('YOU ARE SOMEWHAT CLOSER TO THE NUMBER')
                comparision(x,y)
            elif x-y>=5 and x-y<10:
                print('YOU ARE CLOSE')
                comparision(x,y)
            elif x-y>=1 and x-y<5:
                print('YOU ARE VERY CLOSE')
                comparision(x,y)
            elif x-y<=-50:
                print('YOU ARE TOO FAR AWAY')
                comparision(x,y)
            elif x-y<=-30 and x-y>-50:
                print('YOU ARE MUCH FAR FROM NUMBER')
                comparision(x,y)
            elif x-y<=-20 and x-y>-30:
                print('YOU ARE STILL FAR')
                comparision(x,y)
            elif x-y<=-10 and x-y>-20:
                print('YOU ARE SOMEWHAT CLOSER TO THE NUMBER')
                comparision(x,y)
            elif x-y<=-5 and x-y>-10:
                print('YOU ARE CLOSE')
                comparision(x,y)
            elif x-y<=-1 and x-y>-5:
                print('YOU ARE VERY CLOSE')
                comparision(x,y)
            

   
def number_guesser():
        x= int(input('ASK YOUR FRIEND TO ENTER A NUMBER THAT HE WANT YOU TO GUESS BTW 1 TO 51'))
        y=int(input('Enter the number you gueesed:-'))
        print('YOUR GUESS IS:',y)
        

        if x==y:
            print('YOU GUESSED THE RIGHT NUMBER IN THE FIRST INSTANCE')
            print('THE RIGHT NUMBER IS',x)
        else:
            if x-y>=50:
                print('YOU ARE TOO FAR AWAY')
            elif x-y>=30 and x-y<50:
                print('YOU ARE MUCH FAR FROM NUMBER')
            elif x-y>=20 and x-y<30:
                print('YOU ARE STILL FAR')
            elif x-y>=10 and x-y<20:
                print('YOU ARE SOMEWHAT CLOSER TO THE NUMBER')
            elif x-y>=5 and x-y<10:
                print('YOU ARE CLOSE')
            elif x-y>=1 and x-y<5:
                print('YOU ARE VERY CLOSE')
            elif x-y<=-50:
                print('YOU ARE TOO FAR AWAY')
            elif x-y<=-30 and x-y>-50:
                print('YOU ARE MUCH FAR FROM NUMBER')
            elif x-y<=-20 and x-y>-30:
                print('YOU ARE STILL FAR')
            elif x-y<=-10 and x-y>-20:
                print('YOU ARE SOMEWHAT CLOSER TO THE NUMBER')
            elif x-y<=-5 and x-y>-10:
                print('YOU ARE CLOSE')
            elif x-y<=-1 and x-y>-5:
                print('YOU ARE VERY CLOSE')
        comparision(x,y)
            

            

       
    
number_guesser()
# Out:
# YOUR GUESS IS: 30
# YOU ARE CLOSE
# THE NUMBER YOU NOW GUESSED IS: 27
# YOU ARE VERY CLOSE
# THE NUMBER YOU NOW GUESSED IS: 23
# NOW THE GUESSED NUMBER IS RIGHT THE ANSWER WAS: 23
